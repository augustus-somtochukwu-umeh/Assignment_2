# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/umeha/Downloads/food_coded.csv")
df.head(10)
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           NaN           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
# 5   2.25       1          1               610           3.0           980.0
# 6    3.8       2          1               610           3.0           420.0
# 7    3.3       1          1               720           3.0           420.0
# 8    3.3       1          1               430           NaN           420.0
# 9    3.3       1          1               430           3.0           315.0
#
#    coffee                                  comfort_food  \
# 0       1                                          none
# ...

# %%
missing_values = df.isnull().sum()
missing_values
top5_missing = df.isnull().sum() .sort_values(ascending=False).head(5)
top5_missing
# Out:
# type_sports                   26
# comfort_food_reasons_coded    19
# calories_day                  19
# cuisine                       17
# exercise                      13
# dtype: int64

# %%
df.dtypes
for col in df.columns:
    types = df[col].apply(type).value_counts()
    if len(types) > 1:
        print(f"\nColumn: {col}")
        print(types)
# Out:
# Column: GPA
# GPA
# <class 'str'>      123
# <class 'float'>      2
# Name: count, dtype: int64
#
# Column: comfort_food
# comfort_food
# <class 'str'>      124
# <class 'float'>      1
# Name: count, dtype: int64
#
# Column: comfort_food_reasons
# comfort_food_reasons
# <class 'str'>      123
# <class 'float'>      2
# Name: count, dtype: int64
#
# Column: diet_current
# diet_current
# <class 'str'>      124
# <class 'float'>      1
# Name: count, dtype: int64
#
# Column: eating_changes
# eating_changes
# <class 'str'>      122
# <class 'float'>      3
# Name: count, dtype: int64
#
# Column: father_profession
# father_profession
# <class 'str'>      122
# <class 'float'>      3
# Name: count, dtype: int64
#
# Column: fav_cuisine
# fav_cuisine
# <class 'str'>      123
# <class 'float'>      2
# Name: count, dtype: int64
#
# Column: food_childhood
# food_childhood
# <class 'str'>      124
# <class 'float'>      1
# Name: count, dtype: int64
#
# Column: healthy_meal
# healthy_meal
# ...

# %%
df["GPA"] = df["GPA"].replace(["", "NA", "N/A", "na", "Unknown", "n/a"], np.nan)
df["calories_day"] = df["calories_day"].fillna(df["calories_day"].mean())
df[["GPA", "calories_day"]].isnull().sum()
# Out:
# GPA             3
# calories_day    0
# dtype: int64

# %%
df["GPA"]
# Out:
# 0        2.4
# 1      3.654
# 2        3.3
# 3        3.2
# 4        3.5
#        ...
# 120      3.5
# 121        3
# 122    3.882
# 123        3
# 124      3.9
# Name: GPA, Length: 125, dtype: str

# %%
#gender_map = {
 ####df["Gender"] = df["Gender"].map(gender_map)
#df["Gender"].value_counts(dropna=False)
df["Gender"].unique()
# Out:
# <StringArray>
# [nan]
# Length: 1, dtype: str
